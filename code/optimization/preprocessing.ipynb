# %% [markdown]
# # Preprocessing Data

# %%
import pandas as pd

# %%
data = pd.read_csv('../crypto_pairs.csv')

# We define the list of tokens we want to use 
optim_env = ['BNT/ETH', 
            'SNT/ETH', 
            'ENJ/ETH', 
            'LEND/ETH', 
            'LRC/ETH',  
            'POWR/ETH']

# %%
data_optim = data[data['symbol'].isin(optim_env)]
data_optim
# Out:
#       Unnamed: 0      timestamp        date        source    symbol      open  \
# 5000        5000  1560211200000  2019-06-11  ccxt_binance   BNT/ETH  0.002848
# 5001        5001  1560297600000  2019-06-12  ccxt_binance   BNT/ETH  0.002883
# 5002        5002  1560384000000  2019-06-13  ccxt_binance   BNT/ETH  0.002862
# 5003        5003  1560470400000  2019-06-14  ccxt_binance   BNT/ETH  0.002830
# 5004        5004  1560556800000  2019-06-15  ccxt_binance   BNT/ETH  0.002763
# ...          ...            ...         ...           ...       ...       ...
# 7995        7995  1602979200000  2020-10-18  ccxt_binance  POWR/ETH  0.000218
# 7996        7996  1603065600000  2020-10-19  ccxt_binance  POWR/ETH  0.000215
# 7997        7997  1603152000000  2020-10-20  ccxt_binance  POWR/ETH  0.000212
# 7998        7998  1603238400000  2020-10-21  ccxt_binance  POWR/ETH  0.000210
# 7999        7999  1603324800000  2020-10-22  ccxt_binance  POWR/ETH  0.000209
#
#       total_volume
# ...
